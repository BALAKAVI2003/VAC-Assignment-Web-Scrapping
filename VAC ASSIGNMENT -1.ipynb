# %%
pip install bs4

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "https://www.flipkart.com/laptops-store?s_kwcid=AL!739!3!582822043916!e!!g!!flipkart&gclsrc=aw.ds&&semcmpid=sem_8024046704_sitelink_laptop_goog"

# %%
allow = requests.get(url)

# %%
allow
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
laptop_name = soup.select(".s1Q9rs")

# %%
laptop_name
# Out:
# [<a class="s1Q9rs" href="/lenovo-ideapad-3-core-i3-10th-gen-8-gb-256-gb-ssd-windows-11-home-15iml05-thin-light-laptop/p/itmd1871bfcde765?pid=COMG6AKVAHWTHAQG&amp;lid=LSTCOMG6AKVAHWTHAQGXUICJF&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_bbccbcbb-3279-4f1c-91b5-74dd45f8293f_15_Z64DOAITRPKB_MC.COMG6AKVAHWTHAQG&amp;ppt=None&amp;ppn=None&amp;ssid=wvk0z15kw00000001653827565860&amp;otracker=clp_pmu_v2_Best%2BSelling%2BLaptop_1_15.productCard.PMU_V2_Lenovo%2BIdeaPad%2B3%2BCore%2Bi3%2B10th%2BGen%2B-%2B%25288%2BGB%252F256%2BGB%2BSSD%252FWindows%2B11%2BHome%2529%2B15IML05%2BThin%2Band%2BLight%2BLaptop_laptops-store_COMG6AKVAHWTHAQG_neo%2Fmerchandising_0&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Best%2BSelling%2BLaptop_LIST_productCard_cc_1_NA_view-all&amp;cid=COMG6AKVAHWTHAQG" rel="noopener noreferrer" target="_blank" title="Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) 15IML05 Thin and Light Laptop">Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/2
# ...

# %%
laptop = []
junk = []

# %%
for item in laptop_name:
    laptop.append(item.text)
    link = "https://www.flipkart.com"
    junk.append(link)

# %%
laptop
# Out:
# ['Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 H...',
#  'HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq262...',
#  'HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/Windows 10 Home) 15...',
#  'Lenovo Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15IML...',
#  'HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 10...',
#  'ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 GB/512 GB SSD/Windo...',
#  'HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 14...',
#  'ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 1...',
#  'ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 GB/1 TB HDD/256 GB ...',
#  'MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/512 GB SSD/Windows ...',
#  'Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen - (8 GB/512 GB SSD...',
#  'Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windo...',
#  'Electrobot Intel Core i5-650 (8 GB RAM/Integrated Graphics/1 TB H...',
# ...

# %%
rate_list = soup.select("._30jeq3")

# %%
rate_list
# Out:
# [<div class="_30jeq3">₹34,990</div>,
#  <div class="_30jeq3">₹41,990</div>,
#  <div class="_30jeq3">₹34,990</div>,
#  <div class="_30jeq3">₹38,490</div>,
#  <div class="_30jeq3">₹57,990</div>,
#  <div class="_30jeq3">₹36,990</div>,
#  <div class="_30jeq3">₹49,490</div>,
#  <div class="_30jeq3">₹57,990</div>,
#  <div class="_30jeq3">₹47,990</div>,
#  <div class="_30jeq3">₹43,990</div>,
#  <div class="_30jeq3">₹50,990</div>,
#  <div class="_30jeq3">₹47,490</div>,
#  <div class="_30jeq3">₹14,899</div>,
#  <div class="_30jeq3">₹6,499</div>,
#  <div class="_30jeq3">₹10,899</div>,
#  <div class="_30jeq3">₹18,889</div>,
#  <div class="_30jeq3">₹6,265</div>,
#  <div class="_30jeq3">₹9,499</div>,
#  <div class="_30jeq3">₹23,990</div>,
#  <div class="_30jeq3">₹22,990</div>,
#  <div class="_30jeq3">₹22,990</div>,
#  <div class="_30jeq3">₹21,999</div>,
#  <div class="_30jeq3">₹20,499</div>,
#  <div class="_30jeq3">₹20,490</div>]

# %%
rate = []

# %%
for item in rate_list:
    rate.append(item.text)

# %%
rate
# Out:
# ['₹34,990',
#  '₹41,990',
#  '₹34,990',
#  '₹38,490',
#  '₹57,990',
#  '₹36,990',
#  '₹49,490',
#  '₹57,990',
#  '₹47,990',
#  '₹43,990',
#  '₹50,990',
#  '₹47,490',
#  '₹14,899',
#  '₹6,499',
#  '₹10,899',
#  '₹18,889',
#  '₹6,265',
#  '₹9,499',
#  '₹23,990',
#  '₹22,990',
#  '₹22,990',
#  '₹21,999',
#  '₹20,499',
#  '₹20,490']

# %%
review_list = soup.select("._3LWZlK")

# %%
review_list
# Out:
# [<div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.4<img class="_1wB99o" src="..."/></div>,
# ...

# %%
review = []

# %%
for item in review_list:
    review.append(item.text)

# %%
review
# Out:
# ['4.3',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.5',
#  '4.3',
#  '4.4',
#  '4.5',
#  '4.3',
#  '4.5',
#  '4.3',
#  '4.3',
#  '3.7',
#  '3.4',
#  '4.1',
#  '3.9',
#  '3.5',
#  '3.9',
#  '4',
#  '4.1',
#  '3.8',
#  '4.1',
#  '3.8',
#  '3.8']

# %%
import pandas as pd

# %%
laptop = pd.DataFrame(laptop,columns=["Laptop_name"])

# %%
laptop["Rate"]= rate

# %%
laptop["Review"]= review

# %%
laptop
# Out:
#                                           Laptop_name     Rate Review
# 0   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹34,990    4.3
# 1   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹41,990    4.3
# 2   HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/...  ₹34,990    4.3
# 3   Lenovo Core i3 10th Gen - (8 GB/512 GB SSD/Win...  ₹38,490    4.4
# 4   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...  ₹57,990    4.5
# 5   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹36,990    4.3
# 6   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹49,490    4.4
# 7   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹57,990    4.5
# 8   ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...  ₹47,990    4.3
# 9   MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/...  ₹43,990    4.5
# 10  Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen...  ₹50,990    4.3
# 11  Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...  ₹47,490    4.3
# ...

# %%
laptop.to_csv("laptop.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24788/582978404.py in <module>
# ----> 1 laptop.to_csv("laptop.csv")
#
# NameError: name 'laptop' is not defined
